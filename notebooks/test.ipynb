# %%
from web_2_pdf_PlayWright import save_webpages_to_pdf

urls = ["https://data.who.int/dashboards/covid19/circulation"]
res = await save_webpages_to_pdf(urls, format="A0", margin="0mm")
for r in res:
    print(r["ok"], r["url"], r["path"], r["error"])
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[5], line 4
#       1 from web_2_pdf_PlayWright import save_webpages_to_pdf
#       3 urls = ["https://data.who.int/dashboards/covid19/circulation"]
# ----> 4 res = await save_webpages_to_pdf(urls, format="A0", margin="0mm")
#       5 for r in res:
#       6     print(r["ok"], r["url"], r["path"], r["error"])
#
# File ~/Desktop/预防预警算法集成/cn_cdc_data/web_2_pdf_PlayWright.py:207, in save_webpages_to_pdf(urls, output, format, margin, scale, concurrency, timeout, wait_until, delay, user_agent, headless, browser_args)
#     204     browser_args = ["--disable-gpu"]
#     206 async with async_playwright() as p:
# --> 207     browser = await p.chromium.launch(headless=headless, args=browser_args)
#     208     context = await browser.new_context(locale="zh-CN", user_agent=user_agent)
#     210     async def _worker(u: str) -> None:
# ...
